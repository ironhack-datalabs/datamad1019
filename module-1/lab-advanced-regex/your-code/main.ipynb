# %% [markdown]
# # Advanced Regular Expressions Lab
#
# Complete the following set of exercises to solidify your knowledge of regular expressions.

# %%
import re

# %% [markdown]
# ### 1. Use a regular expression to find and extract all vowels in the following text.

# %%
text = "This is going to be a sentence with a good number of vowels in it."

# %%
vowels=re.findall("[a,e,i,o,u]",text)
print(vowels)
print(len(vowels))
# Out:
# ['i', 'i', 'o', 'i', 'o', 'e', 'a', 'e', 'e', 'e', 'i', 'a', 'o', 'o', 'u', 'e', 'o', 'o', 'e', 'i', 'i']
# 21

# %% [markdown]
# ### 2. Use a regular expression to find and extract all occurrences and tenses (singular and plural) of the word "puppy" in the text below.

# %%
text = "The puppy saw all the rest of the puppies playing and wanted to join them. I saw this and wanted a puppy of my own!"

# %%
puppies= re.findall('pupp\S*',text)
print(puppies)
# Out:
# ['puppy', 'puppies', 'puppy']

# %% [markdown]
# ### 3. Use a regular expression to find and extract all tenses (present and past) of the word "run" in the text below.

# %%
text1 = "I ran the relay race the only way I knew how to run it."

# %%
run= re.findall('run|ran',text1)
print(run)
# Out:
# ['ran', 'run']

# %% [raw]
# ### 4. Use a regular expression to find and extract all words that begin with the letter "r" from the previous text.

# %%
text1 = "I ran the relay race the only way I knew how to run it."
words_withr= re.findall ('()', text1)
print(words_withr)
print(type(words_withr))
print(words_withr[1])
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# <class 'list'>

# %% [markdown]
# ### 5. Use a regular expression to find and substitute the letter "i" for the exclamation marks in the text below.

# %%
text2 = "This is a sentence with special characters in it."

# %%
text2 = "This is a sentence with special characters in it."
variable= re.sub('i','!', text2)
print(variable)
# Out:
# Th!s !s a sentence w!th spec!al characters !n !t.

# %% [markdown]
# ### 6. Use a regular expression to find and extract words longer than 4 characters in the text below.

# %%
text3 = "This sentence has words of varying lengths."
exact= re.findall ('\w{5,}', text3)
print(exact)
# Out:
# ['sentence', 'words', 'varying', 'lengths']

# %% [markdown]
# ### 7. Use a regular expression to find and extract all occurrences of the letter "b", some letter(s), and then the letter "t" in the sentence below.

# %%
text4 = "I bet the robot couldn't beat the other bot with a bat, but instead it bit me."

# %% [markdown]
# ### 8. Use a regular expression to find and extract all words that contain either "ea" or "eo" in them.

# %%
text5 = "During many of the peaks and troughs of history, the people living it didn't fully realize what was unfolding. But we all know we're navigating breathtaking history: Nearly every day could be — maybe will be — a book."
eaeo= re.findall ('\w+eo\w*|\w+ea\w*', text5)
print (eaeo)
# Out:
# ['peaks', 'people', 'realize', 'breathtaking', 'Nearly']

# %% [markdown]
# ### 9. Use a regular expression to find and extract all the capitalized words in the text below individually.

# %%
text6 = "Teddy Roosevelt and Abraham Lincoln walk into a bar."

# %%
capitalized=re.findall('[A-Z]\w*',text6)
print(capitalized)
# Out:
# ['Teddy', 'Roosevelt', 'Abraham', 'Lincoln']

# %% [markdown]
# ### 10. Use a regular expression to find and extract all the sets of consecutive capitalized words in the text above.

# %%
consecutive=re.findall('[T,A]\w+\W\w+',text6)
print(consecutive)
# Out:
# ['Teddy Roosevelt', 'Abraham Lincoln']

# %% [markdown]
# ### 11. Use a regular expression to find and extract all the quotes from the text below.
#
# *Hint: This one is a little more complex than the single quote example in the lesson because there are multiple quotes in the text.*

# %%
text7 = 'Roosevelt says to Lincoln, "I will bet you $50 I can get the bartender to give me a free drink." Lincoln says, "I am in!"'

# %%
quotes=re.findall('".+\."|".+\!"',text7)
print(quotes)
# Out:
# ['"I will bet you $50 I can get the bartender to give me a free drink."', '"I am in!"']

# %% [markdown]
# ### 12. Use a regular expression to find and extract all the numbers from the text below.

# %%
text8 = "There were 30 students in the class. Of the 30 students, 14 were male and 16 were female. Only 10 students got A's on the exam."

# %%
digits=re.findall('\d+', text8)
print(digits)
# Out:
# ['30', '30', '14', '16', '10']

# %% [markdown]
# ### 13. Use a regular expression to find and extract all the social security numbers from the text below.

# %%
text9 = """
Henry's social security number is 876-93-2289 and his phone number is (847)789-0984.
Darlene's social security number is 098-32-5295 and her phone number is (987)222-0901.
"""

# %%
ss=re.findall('\d+-\d+-\d+',text9)
print(ss)
# Out:
# ['876-93-2289', '098-32-5295']

# %% [markdown]
# ### 14. Use a regular expression to find and extract all the phone numbers from the text below.

# %%
phone=re.findall('\(\d+\)\d+\-\d+',text9)
print(phone)
# Out:
# ['(847)789-0984', '(987)222-0901']

# %% [markdown]
# ### 15. Use a regular expression to find and extract all the formatted numbers (both social security and phone) from the text below.

# %%
all=re.findall('\(*\d+\W\d+-\d+',text9)
print(all)
# Out:
# ['876-93-2289', '(847)789-0984', '098-32-5295', '(987)222-0901']
