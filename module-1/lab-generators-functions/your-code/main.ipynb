# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %% [markdown]
# # Challenge 1 - Functions.
#
# A function is a block of organized, reusable code that is used to perform a single, related action. Functions provide better modularity for your application and a high degree of code reusing. Create un function to find the summation of the number of every number from 1 to num.

# %%
num=76

# %%
# Usando funciones predefinidas (sum):
def summation(num):
    # This function returns 1+2+3+....+num
    return(sum(range(1,num+1)))
print(summation(76))


# Sin usar funciones predefinidas:
def summation(num):
    suma = 0
    for e in range(1,num+1):
        suma += e
    return(suma)
# print(summation(76))
# Out:
# 2926

# %% [markdown]
# # Challenge 2 - Positional arguments, Args and Kwargs.
#
# The syntax *args and **kwargs in function definitions is used to pass a variable number of arguments to a function. The single asterisk form (*args) is used to pass a non-keyworded, variable-length argument list, and the double asterisk form is used to pass a keyworded, variable-length argument list. Create a function to find the summation of all elements of the array.

# %%
array=[3, 8, 16]

# %%
def summation2(*args):
    # This function returns the sum of *args
    return(sum(args))
summation2(*array)
# Out:
# 27

# %% [markdown]
# Now, do the same thing with positional arguments.

# %%
def summation3(a, b, c):
    # This function returns a+b+c
    return(a+b+c)
summation3(*array)
# Out:
# 27

# %% [markdown]
# Given the next dictionary of M&Ms, create a function to sum all non red M&Ms.

# %%
dictionary={'red':3, 'blue':8, 'green':24, 'orange':12, 'purple':10}

# %%
def summation4(**kwargs):
    # This function returns the sum of all M&Ms, except the red ones
    suma = 0
    for key in kwargs.keys():
        if key != "red":
            suma += kwargs[key]
    return(suma)
print(summation4(**dictionary))
# Out:
# 54

# %% [markdown]
# Below, create a function to sum all following elements.

# %%
a=4
b=6
c=15
d=[48, 465, 23, 96]
e={'A':16, 'B':32, 'C':64}

# %%
def summation5(*args,**kwargs):
    # This function returns the sum of a,b,c,d and e
    suma = sum(args)
    for key in kwargs.keys():
        suma += kwargs[key]  
    return(suma)
summation5(a,b,c,*d,**e)
# Out:
# 769

# %% [markdown]
# # Challenge 3 - Iterators, Generators and `yield`.
#
# In iterator in Python is an object that represents a stream of data. However, iterators contain a countable number of values. We traverse through the iterator and return one value at a time. All iterators support a `next` function that allows us to traverse through the iterator. We can create an iterator using the `iter` function that comes with the base package of Python. Below is an example of an iterator.

# %%
# We first define our iterator:

iterator = iter([1,2,3])

# We can now iterate through the object using the next function

print(next(iterator))
# Out:
# 1

# %%
# We continue to iterate through the iterator.

print(next(iterator))
# Out:
# 2

# %%
print(next(iterator))
# Out:
# 3

# %%
# After we have iterated through all elements, we will get a StopIteration Error

print(next(iterator))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-106-91070dc82d50> in <module>
#       1 # After we have iterated through all elements, we will get a StopIteration Error
#       2
# ----> 3 print(next(iterator))
#
# StopIteration:

# %%
# We can also iterate through an iterator using a for loop like this:
# Note: we cannot go back directly in an iterator once we have traversed through the elements. 
# This is why we are redefining the iterator below

iterator = iter([1,2,3])

for i in iterator:
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# In the cell below, write a function that takes an iterator and returns the first element in the iterator and returns the first element in the iterator that is divisible by 2. Assume that all iterators contain only numeric data. If we have not found a single element that is divisible by 2, return zero.

# %%
def divisible2(iterator):
    # This function takes an iterable and returns the first element that is divisible by 2 and zero otherwise
    # Input: Iterable
    # Output: Integer
    count = 0
    divisible=[]
    for i in iterator:
        if i % 2 == 0:
            divisible.append(i)
    if len(divisible) > 0:
        return(divisible[0]) # [0] porque queremos sólo el primer divisible, no todos los que haya encontrado
    else:
        return 0 # Si la longitud de 'divisible' es 0, el loop no ha encontrado ningún número par en todo el iterador

# Lo pruebo con distintos iterators para comprobar que funcione:
print(divisible2(iter([1,2,3]))) # Sample Output: 2
print(divisible2(iter([1,3,3])))
print(divisible2(iter([1,2,2])))
print(divisible2(iter([1,3,5,6,4,2,2])))
# Out:
# 2
# 0
# 2
# 6

# %% [markdown]
# ### Generators
#
# It is quite difficult to create your own iterator since you would have to implement a `next` function. Generators are functions that enable us to create iterators. The difference between a function and a generator is that instead of using `return`, we use `yield`. For example, below we have a function that returns an iterator containing the numbers 0 through n:

# %%
def firstn(n):
     number = 0
     while number < n:
         yield number
         number = number + 1

# %% [markdown]
# If we pass 5 to the function, we will see that we have a iterator containing the numbers 0 through 4.

# %%
iterator = firstn(5)

for i in iterator:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# In the cell below, create a generator that takes a number and returns an iterator containing all even numbers between 0 and the number you passed to the generator.

# %%
def even_iterator(n):
    # This function produces an iterator containing all even numbers between 0 and n
    # Input: integer
    # Output: iterator
    # Your code here:
    number = 0
    while number < n:
        yield number
        number = number + 2


# Lo pruebo con distintos inputs para comprobar que funcione:
# Sample Input: 5
iterator = even_iterator(5)
pares = []
for i in iterator:
    pares.append(i)
print("pares:", *pares) # Sample Output: iter([0, 2, 4])
    
# Sample Input: 13
iterator = even_iterator(13)
pares = []
for i in iterator:
    pares.append(i)
print("pares:", *pares)
# Out:
# pares: 0 2 4
# pares: 0 2 4 6 8 10 12
