# %% [markdown]
# ## Challenge 1: Tuples
#
# #### Do you know you can create tuples with only one element?
#
# **In the cell below, define a variable `tup` with a single element `"I"`.**
#
# *Hint: you need to add a comma (`,`) after the single element.*

# %%
tup = ("I",)
print(tup)
# Out:
# ('I',)

# %% [markdown]
# #### Print the type of `tup`.
#
# Make sure its type is correct (i.e. *tuple* instead of *str*).

# %%
print(type(tup))
# Out:
# <class 'tuple'>

# %% [markdown]
# #### Now try to append the following elements to `tup`.
#
# Are you able to do it? Explain.
#
# ```
# "r", "o", "n", "h", "a", "c", "k',
# ```

# %%
other_values = ["r", "o", "n", "h", "a", "c", "k"]
tup_list = list(tup)
for i in other_values:
    tup_list.append(i)
tup = tuple(tup_list)
print(tup)
# Explanation:
# Since tuples are an inmmutable data structure one can not alter its content (add new values or remove old ones) 
# hence the only way to achieve this is by transforming the tuple to a list (creating a new list using list() function), 
# modifying it (iterating over the list) and then transforming the list back to a tuple.
# Instead of a list one could also use a string.
# Out:
# ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k')

# %% [markdown]
# #### How about re-assign a new value to an existing tuple?
#
# Re-assign the following elements to `tup`. Are you able to do it? Explain.
#
# ```
# "I", "r", "o", "n", "h", "a", "c", "k"
# ```

# %%
tup_list.clear()
tup_list = list(tup)
tup_list[0] = "i"
tup = tuple(tup_list)
print(tup)
# Explanation:
# Again, since tuples are inmutable one has to convert it to a data structure that is mutable (i.e. list, string) 
# then modify it and create a new tuple (using tuple() function) that contains the modified element.
# Out:
# ('i', 'r', 'o', 'n', 'h', 'a', 'c', 'k')

# %% [markdown]
# #### Split `tup` into `tup1` and `tup2` with 4 elements in each.
#
# `tup1` should be `("I", "r", "o", "n")` and `tup2` should be `("h", "a", "c", "k")`.
#
# *Hint: use positive index numbers for `tup1` assignment and use negative index numbers for `tup2` assignment. Positive index numbers count from the beginning whereas negative index numbers count from the end of the sequence.*
#
# Also print `tup1` and `tup2`.

# %%
tup1 = tup[0:4]
tup2 = tup[-4:]
print(tup1)
print(tup2)
# Out:
# ('i', 'r', 'o', 'n')
# ('h', 'a', 'c', 'k')

# %% [markdown]
# #### Add `tup1` and `tup2` into `tup3` using the `+` operator.
#
# Then print `tup3` and check if `tup3` equals to `tup`.

# %%
tup3 = tup1 + tup2
print(tup3)
print(tup3 == tup)
# Out:
# ('i', 'r', 'o', 'n', 'h', 'a', 'c', 'k')
# True

# %% [markdown]
# #### Count the number of elements in `tup1` and `tup2`. Then add the two counts together and check if the sum is the same as the number of elements in `tup3`

# %%
count_tup1 = len(tup1)
count_tup2 = len(tup2)
print(count_tup1)
print(count_tup2)
# Out:
# 4
# 4

# %% [markdown]
# #### What is the index number of `"h"` in `tup3`?

# %%
print(tup3[4])
# Out:
# i

# %% [markdown]
# #### Now, use a FOR loop to check whether each letter in the following list is present in `tup3`:
#
# ```
# letters = ["a", "b", "c", "d", "e"]
# ```
#
# For each letter you check, print `True` if it is present in `tup3` otherwise print `False`.
#
# *Hint: you only need to loop `letters`. You don't need to loop `tup3` because there is a Python operator `in` you can use. See [reference](https://stackoverflow.com/questions/17920147/how-to-check-if-a-tuple-contains-an-element-in-python).*

# %%
letters = ["a", "b", "c", "d", "e"]
for i in letters:
    if i in tup3:
            print("True")
    else:
        print("False")
# Out:
# True
# False
# True
# False
# False

# %% [markdown]
# #### How many times does each letter in `letters` appear in `tup3`?
#
# Print out the number of occurrence of each letter.

# %%
letters = ["a", "b", "c", "d", "e"]
for i in letters:
    instance_of_a = 0
    instance_of_b = 0
    instance_of_c = 0
    instance_of_d = 0
    instance_of_e = 0
    for j in tup3:
        if i == j:
            if i == "a":
                instance_of_a += 1
                print("letter a is repeated", instance_of_a, "time/s.")
            elif i == "b":
                instance_of_b += 1
                print("letter b is repeated", instance_of_b, "time/s.")
            elif i == "c":
                instance_of_c += 1
                print("letter c is repeated", instance_of_c, "time/s.")
            elif i == "d":
                instance_of_d += 1
                print("letter d is repeated", instance_of_d, "time/s.")
            elif i == "e":
                instance_of_e += 1
                print("letter e is repeated", instance_of_e, "time/s.")
            else:
                print("none of the letters appear in tup3")
# Out:
# letter a is repeated 1 time/s.
# letter c is repeated 1 time/s.
