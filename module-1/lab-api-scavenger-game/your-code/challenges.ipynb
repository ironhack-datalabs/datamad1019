# %%
import json
import requests
from IPython.display import Image
from IPython.core.display import HTML 
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
def githubRequestAuthorized(resource):
    authToken = os.getenv("GITHUB_API_TOKEN")
    if not authToken:
        raise ValueError("NECESITAS UN TOKEN")
    else:
        print("We have a github token: ", authToken[0:4])
    headers = {
        "Authorization": "token {}".format(authToken)
    }
    url = "https://api.github.com{}".format(resource)
    print("Requesting authorized {}".format(url))
    res = requests.get(url, headers=headers)
    return res

# %% [markdown]
# ## Challenge 1

# %%
forks = githubRequestAuthorized("/repos/ironhack-datalabs/datamad1019/forks").json()
# Out:
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/datamad1019/forks

# %%
display(forks)
# Out:
# [{'id': 218253546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTgyNTM1NDY=',
#   'name': 'datamad1019',
#   'full_name': 'begoechavarren/datamad1019',
#   'private': False,
#   'owner': {'login': 'begoechavarren',
#    'id': 52955181,
#    'node_id': 'MDQ6VXNlcjUyOTU1MTgx',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/52955181?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/begoechavarren',
#    'html_url': 'https://github.com/begoechavarren',
#    'followers_url': 'https://api.github.com/users/begoechavarren/followers',
#    'following_url': 'https://api.github.com/users/begoechavarren/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/begoechavarren/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/begoechavarren/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/begoechavarren/subscriptions',
#    'organizations_url': 'https://api.github.com/users/begoechavarren/orgs',
# ...

# %%
languages_url = [e['languages_url'] for e in forks]

# %%
print(languages_url)
# Out:
# ['https://api.github.com/repos/begoechavarren/datamad1019/languages', 'https://api.github.com/repos/mariobru/datamad1019/languages', 'https://api.github.com/repos/jlmingo/datamad1019/languages', 'https://api.github.com/repos/Ovion/datamad1019/languages', 'https://api.github.com/repos/ToniPons97/datamad1019/languages', 'https://api.github.com/repos/noeliacarrion/datamad1019/languages', 'https://api.github.com/repos/mariaadradosr/datamad1019/languages', 'https://api.github.com/repos/Juliopdata/datamad1019/languages', 'https://api.github.com/repos/guzmanueco/datamad1019/languages', 'https://api.github.com/repos/blancaalcala/datamad1019/languages', 'https://api.github.com/repos/AlexMndzF/datamad1019/languages', 'https://api.github.com/repos/David-Fde/datamad1019/languages', 'https://api.github.com/repos/MaikaRG/datamad1019/languages', 'https://api.github.com/repos/Turandot123/datamad1019/languages', 'https://api.github.com/repos/isagc/datamad1019/languages', 'https://api.github.com/repos
# ...

# %%
users_path = []
for i in languages_url:
    users_path.append(i[28:])

# %%
print(users_path)
# Out:
# ['/begoechavarren/datamad1019/languages', '/mariobru/datamad1019/languages', '/jlmingo/datamad1019/languages', '/Ovion/datamad1019/languages', '/ToniPons97/datamad1019/languages', '/noeliacarrion/datamad1019/languages', '/mariaadradosr/datamad1019/languages', '/Juliopdata/datamad1019/languages', '/guzmanueco/datamad1019/languages', '/blancaalcala/datamad1019/languages', '/AlexMndzF/datamad1019/languages', '/David-Fde/datamad1019/languages', '/MaikaRG/datamad1019/languages', '/Turandot123/datamad1019/languages', '/isagc/datamad1019/languages', '/alfpml/datamad1019/languages', '/mermora97/datamad1019/languages', '/jm-cruz-d/datamad1019/languages', '/blancalluch/datamad1019/languages', '/albertovpd/datamad1019/languages', '/mariaversin/datamad1019/languages', '/seorakwon/datamad1019/languages', '/Jpereza24/datamad1019/languages', '/castares/datamad1019/languages', '/progameitor/datamad1019/languages', '/Masdevallia/datamad1019/languages', '/cprietosegura/datamad1019/languages', '/jgph91
# ...

# %%
#languages = set([e['language'] for e in forks])

# %%
lang = []
for e in users_path:
    users = githubRequestAuthorized("/repos{}".format(e)).json()
    lang.append(list(users.keys()))
# Out:
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/begoechavarren/datamad1019/languages
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/mariobru/datamad1019/languages
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/jlmingo/datamad1019/languages
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/Ovion/datamad1019/languages
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ToniPons97/datamad1019/languages
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/noeliacarrion/datamad1019/languages
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/mariaadradosr/datamad1019/languages
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/Juliopdata/datamad1019/languages
# We have a github token:  5003
# ...

# %%
print(lang)
# Out:
# [['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'], ['Jupyter Notebook', 'HTML', 'Python'
# ...

# %%
flatten = [item for sublist in lang for item in sublist]

# %%
print(set(flatten))
# Out:
# {'Jupyter Notebook', 'HTML', 'Python'}

# %% [markdown]
# ## Challenge 2

# %% [markdown]
# Como no se han hecho commits en la última semana, he sacado los commits que se han hecho desde el inicio del bootcamp.

# %%
commits = githubRequestAuthorized("/repos/ironhack-datalabs/datamad1019/commits?since=2019-10-21T00:00:00Z").json()
# Out:
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/datamad1019/commits?since=2019-10-21T00:00:00Z

# %%
commits
# Out:
# [{'sha': '736943a50f626e98be1b6da8dcf12c36b48f1cb7',
#   'node_id': 'MDY6Q29tbWl0MjE2NTc2NDQzOjczNjk0M2E1MGY2MjZlOThiZTFiNmRhOGRjZjEyYzM2YjQ4ZjFjYjc=',
#   'commit': {'author': {'name': 'Marc Pomar',
#     'email': 'marc@faable.com',
#     'date': '2019-10-21T10:56:46Z'},
#    'committer': {'name': 'Marc Pomar',
#     'email': 'marc@faable.com',
#     'date': '2019-10-21T10:56:46Z'},
#    'message': 'listo',
#    'tree': {'sha': 'c1a56f120fe4f229cb72f20bf384ba236de594df',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1019/git/trees/c1a56f120fe4f229cb72f20bf384ba236de594df'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1019/git/commits/736943a50f626e98be1b6da8dcf12c36b48f1cb7',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/ironhack-datalabs/datamad1019/commits/736943a50f626e98be1b6da8dcf12c36b48f1cb7',
# ...

# %%
print("{} commits have been done since the start of the bootcamp".format(len(commits)))
# Out:
# 2 commits have been done since the start of the bootcamp

# %% [markdown]
# ## Challenge 3

# %%
scavenger1 = githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt").json()
# Out:
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt

# %%
scavenger1
# Out:
# {'name': '.0006.scavengerhunt',
#  'path': '15024/.0006.scavengerhunt',
#  'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#  'size': 3,
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#  'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#  'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#  'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#  'type': 'file',
#  'content': 'b2YK\n',
#  'encoding': 'base64',
#  '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#   'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
# ...

# %%
scavenger = githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents").json()
# Out:
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents

# %%
scavenger
# Out:
# [{'name': '.gitignore',
#   'path': '.gitignore',
#   'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'size': 10,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}},
#  {'name': '15024',
#   'path': '15024',
#   'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'size': 0,
# ...

# %%
directories = []
for e in scavenger:
    directories.append(e['name'])

# %%
print(directories)
# Out:
# ['.gitignore', '15024', '15534', '17020', '30351', '40303', '44639', '45525', '47222', '47830', '49418', '50896', '55417', '55685', '60224', '64880', '66032', '68848', '70751', '70985', '88596', '89046', '89338', '91701', '97881', '98750']

# %%
directories.pop(0)
# Out:
# '.gitignore'

# %%
directories = [int(i) for i in directories]

# %%
print(directories)
# Out:
# [15024, 15534, 17020, 30351, 40303, 44639, 45525, 47222, 47830, 49418, 50896, 55417, 55685, 60224, 64880, 66032, 68848, 70751, 70985, 88596, 89046, 89338, 91701, 97881, 98750]

# %%
subdir = []
for d in directories:
    sd = githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents/{}".format(d)).json()
    for e in sd:
        subdir.append(e['name'])
# Out:
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/17020
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/30351
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/40303
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/44639
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/45525
# We have a github token:  5003
# ...

# %%
print(subdir)
# Out:
# ['.0006.scavengerhunt', '40', '74', '99', '.0008.scavengerhunt', '.0012.scavengerhunt', '2', '98', '.0007.scavengerhunt', '46', '97', '.0021.scavengerhunt', '22', '96', '.0022.scavengerhunt', '51', '65', '.0005.scavengerhunt', '76', '91', '.0018.scavengerhunt', '67', '90', '.0016.scavengerhunt', '.0024.scavengerhunt', '7', '89', '.0010.scavengerhunt', '66', '85', '.0014.scavengerhunt', '30', '38', '84', '.0011.scavengerhunt', '4', '83', '.0023.scavengerhunt', '14', '82', '.0020.scavengerhunt', '5', '81', '.0003.scavengerhunt', '1', '80', '3', '57', '79', '28', '47', '77', '.0004.scavengerhunt', '16', '75', '.0019.scavengerhunt', '18', '44', '68', '.0017.scavengerhunt', '11', '59', '.0002.scavengerhunt', '12', '32', '55', '64', '70', '73', '.0013.scavengerhunt', '35', '43', '8', '.0015.scavengerhunt', '33', '39', '.0009.scavengerhunt', '26', '36', '71', '.0001.scavengerhunt', '20', '62']

# %%
hidden = []
for i in subdir:
    if i[0] == '.':
        hidden.append(i)

# %%
for i in hidden:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
file = githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents/{}/{}".format(15024,'.0006.scavengerhunt')).json()
# Out:
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt

# %%
file
# Out:
# {'name': '.0006.scavengerhunt',
#  'path': '15024/.0006.scavengerhunt',
#  'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#  'size': 3,
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#  'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#  'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#  'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#  'type': 'file',
#  'content': 'b2YK\n',
#  'encoding': 'base64',
#  '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#   'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
# ...

# %%
dic_hidden = dict()
for d in directories:
    for f in hidden:
        h = githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents/{}/{}".format(d,str(f))).json()
        if h['name'] == str(f):
            dic_hidden[f] = h['content']
# Out:
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt
# We have a github token:  5003
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0008.scavengerhunt
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-966893f2f50d> in <module>
#       3     for f in hidden:
#       4         h = githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents/{}/{}".format(d,str(f))).json()
# ----> 5         if h['name'] == str(f):
#       6             dic_hidden[f] = h['content']
#       7
#
# KeyError: 'name'
