# %%
import os
from dotenv import load_dotenv
load_dotenv()
import requests

# %%
def githubRequestAuthorized(resource):
    authToken = os.getenv("token")
    if not authToken:
        raise ValueError("NECESITAS UN TOKEN")
    else:
        print("We have a github token: ", authToken[0:4])
    headers = {
        "Authorization": "token {}".format(authToken)
    }
    url = "https://api.github.com{}".format(resource)
    print("Requesting authorized {}".format(url))
    res = requests.get(url, headers=headers)
    return res

# %%
secret =githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents").json()
# Out:
# We have a github token:  dfc8
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents

# %%
secret
# Out:
# [{'name': '.gitignore',
#   'path': '.gitignore',
#   'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'size': 10,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}},
#  {'name': '15024',
#   'path': '15024',
#   'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'size': 0,
# ...

# %%
type(secret)
# Out:
# list

# %%
# me crea muchas tuplas de par values pero no se trabajar con ello. Con items sacas tuplas
for x in secret:
    for y in x.items():
        print(y)
# Out:
# ('name', '.gitignore')
# ('path', '.gitignore')
# ('sha', 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf')
# ('size', 10)
# ('url', 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master')
# ('html_url', 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore')
# ('git_url', 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf')
# ('download_url', 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore')
# ('type', 'file')
# ('_links', {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master', 'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf', 'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'})
# ('name', '15024')
# ('path', '15024')
# ('sha', '2945e51c87ad5da893c954afcf092f06343bbb7d')
# ('size', 0)
# ...

# %%
type(y)
# Out:
# tuple

# %%
lista_carpetas=list(map(lambda repo: repo["name"], secret))
lista_carpetas
# Out:
# ['.gitignore',
#  '15024',
#  '15534',
#  '17020',
#  '30351',
#  '40303',
#  '44639',
#  '45525',
#  '47222',
#  '47830',
#  '49418',
#  '50896',
#  '55417',
#  '55685',
#  '60224',
#  '64880',
#  '66032',
#  '68848',
#  '70751',
#  '70985',
#  '88596',
#  '89046',
#  '89338',
#  '91701',
#  '97881',
#  '98750']

# %%
contenido = []
for e in lista_carpetas:
    contenido.append(githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents/{}".format(e)).json())
# Out:
# We have a github token:  dfc8
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore
# We have a github token:  dfc8
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024
# We have a github token:  dfc8
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534
# We have a github token:  dfc8
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/17020
# We have a github token:  dfc8
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/30351
# We have a github token:  dfc8
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/40303
# We have a github token:  dfc8
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/44639
# We have a github token:  dfc8
# ...

# %%
contenido
# Out:
# [{'name': '.gitignore',
#   'path': '.gitignore',
#   'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'size': 10,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore',
#   'type': 'file',
#   'content': 'LkRTX1N0b3JlCg==\n',
#   'encoding': 'base64',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}},
#  [{'name': '.0006.scavengerhunt',
# ...

# %%
for lista in contenido:
    for otro in lista:
        print(otro)
# Out:
# name
# path
# sha
# size
# url
# html_url
# git_url
# download_url
# type
# content
# encoding
# _links
# ...

# %%
type(otro)
# Out:
# dict

# %%
# no entiendo porque solo me imprime el ultimo
for key, value in otro.items():
    print(key,value)
# Out:
# name 62
# path 98750/62
# sha e69de29bb2d1d6434b8b29ae775ad8c2e48c5391
# size 0
# url https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/62?ref=master
# html_url https://github.com/ironhack-datalabs/scavenger/blob/master/98750/62
# git_url https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391
# download_url https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/98750/62
# type file
# _links {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/62?ref=master', 'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', 'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/98750/62'}

# %%
# no entiendo porque solo me imprime el ultimo
from pandas.io.json import json_normalize
pandas1 = json_normalize(otro)
print(pandas1)
# Out:
#   name      path                                       sha  size  \
# 0   62  98750/62  e69de29bb2d1d6434b8b29ae775ad8c2e48c5391     0
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                             html_url  \
# 0  https://github.com/ironhack-datalabs/scavenger...
#
#                                              git_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                         download_url  type  \
# 0  https://raw.githubusercontent.com/ironhack-dat...  file
#
#                                          _links.self  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                           _links.git  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                          _links.html
# 0  https://github.com/ironhack-datalabs/scavenger...
