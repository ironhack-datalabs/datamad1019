# %% [markdown]
# Challenge 2: Count Commits
#
# Count how many commits were made in the past week.
#
#     Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
#
#     Count how many commit objects are contained in the array.

# %%
import os
import json
import requests
import pandas as pd
from dotenv import load_dotenv
load_dotenv()

# https://developer.github.com/v3/
def githubRequestAuthorized(resource):
    authToken = os.getenv("GITHUB_API_TOKEN")
    if not authToken:
        raise ValueError("NECESITAS UN TOKEN")
    else:
        print("We have a github token: ", authToken[0:4])
    headers = {
        "Authorization": "token {}".format(authToken)
    }
    url = "https://api.github.com{}".format(resource)
    print("Requesting authorized {}".format(url))
    res = requests.get(url, headers=headers)
    return res

# %%
# quiero sacar la author-list

res = requests.get("https://github.com/ironhack-datalabs/datamad1019")
data = githubRequestAuthorized("/repos/ironhack-datalabs/datamad1019/forks").json()

from pandas.io.json import json_normalize
import re

flattened_data = json_normalize(data)
flattened_data = pd.DataFrame(flattened_data)
lst = []
for e in flattened_data["full_name"]:
    a = re.findall("[A-Za-z]+/",e)
    lst.append(a)
    
    
lst = []    
for e in lst:
    a = e[:-1]
    data = githubRequestAuthorized("/repos/{}-datalabs/datamad1019/commits?since=2019-10-31".format(str(a).json()
# Out:
#   File "<ipython-input-18-8ad6ea7a347c>", line 21
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
from pandas.io.json import json_normalize

flattened_data = json_normalize(data)

flattened_data = pd.DataFrame(flattened_data)

#flattened_data = flattened_data[["commit.author.date"]]
display(flattened_data)
# Out:
#            id                           node_id         name  \
# 0   218253546  MDEwOlJlcG9zaXRvcnkyMTgyNTM1NDY=  datamad1019
# 1   216621511  MDEwOlJlcG9zaXRvcnkyMTY2MjE1MTE=  datamad1019
# 2   216605406  MDEwOlJlcG9zaXRvcnkyMTY2MDU0MDY=  datamad1019
# 3   216604985  MDEwOlJlcG9zaXRvcnkyMTY2MDQ5ODU=  datamad1019
# 4   216604842  MDEwOlJlcG9zaXRvcnkyMTY2MDQ4NDI=  datamad1019
# 5   216601556  MDEwOlJlcG9zaXRvcnkyMTY2MDE1NTY=  datamad1019
# 6   216597798  MDEwOlJlcG9zaXRvcnkyMTY1OTc3OTg=  datamad1019
# 7   216597619  MDEwOlJlcG9zaXRvcnkyMTY1OTc2MTk=  datamad1019
# 8   216597485  MDEwOlJlcG9zaXRvcnkyMTY1OTc0ODU=  datamad1019
# 9   216596981  MDEwOlJlcG9zaXRvcnkyMTY1OTY5ODE=  datamad1019
# 10  216590906  MDEwOlJlcG9zaXRvcnkyMTY1OTA5MDY=  datamad1019
# 11  216590080  MDEwOlJlcG9zaXRvcnkyMTY1OTAwODA=  datamad1019
# 12  216589076  MDEwOlJlcG9zaXRvcnkyMTY1ODkwNzY=  datamad1019
# 13  216586161  MDEwOlJlcG9zaXRvcnkyMTY1ODYxNjE=  datamad1019
# ...
