# %% [markdown]
# # Me copio la pokeapi porque es genial

# %%
import requests

def getPokemon(number):
    url = "https://pokeapi.co/api/v2/pokemon/{}".format(number)
    print("Requesting url {}...".format(url))
    res = requests.get(url)
    data = res.json()
    print("done")
    
    return {
        "name": data["name"],
        "image": data["sprites"]["front_default"]
    }

getPokemon(25)
# Out:
# Requesting url https://pokeapi.co/api/v2/pokemon/25...
# done
# {'name': 'pikachu',
#  'image': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/25.png'}

# %%
# and seen the pics in jupyter-lab seems delightful
from IPython.display import Image
from IPython.core.display import HTML 

for i in range(1,10):
    pokemon = getPokemon(i)
    display(Image(url=pokemon["image"]))

# %% [markdown]
# # THE LAB

# %% [markdown]
# # Connecting the API

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# https://developer.github.com/v3/
def githubRequestAuthorized(resource):
    authToken = os.getenv("GITHUB_API_TOKEN")
    if not authToken:
        raise ValueError("NECESITAS UN TOKEN")
    else:
        print("We have a github token: ", authToken[0:4])
    headers = {
        "Authorization": "token {}".format(authToken)
    }
    url = "https://api.github.com{}".format(resource)
    print("Requesting authorized {}".format(url))
    res = requests.get(url, headers=headers)
    return res

# %%
# os.getenv("GITHUB_API_TOKEN")

# %%
data=githubRequestAuthorized("/repos/ironhack-datalabs/datamad1019/forks").json()
# Out:
# We have a github token:  4660
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/datamad1019/forks

# %%
data
# data is a list with dictionaries inside. just navigate through them and try to find the right key

# %% [markdown]
# # Challenge 1

# %%
# list of languages
lang_list = list(map(lambda repo: repo["language"], data))
lang_list = set (lang_list)
print (lang_list)

# there are none because of the characteristics of this data
# Out:
# We have a github token:  4660
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/datamad1019/forks
# {None, 'Jupyter Notebook'}

# %% [markdown]
# # Challenge 2. Get the commits of a concrete folder

# %%
# to get all commits of a concrete folder using git info
# https://github.com/ironhack-datalabs/datamad1019/tree/master/module-1/lab-api-scavenger-game

# %%
data_commits=githubRequestAuthorized("/repos/ironhack-datalabs/mad-oct-2018/commits").json()
# Out:
# We have a github token:  4660
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/commits

# %%
commits=0

for x in data_commits:
    for y in x:
        if y=="commit":
            commits+=1
print("nº of commits= ",commits)
# Out:
# nº of commits=  30

# %% [markdown]
# # Challenge 3: Looking for easter eggs in github repositories

# %%
'''
Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following 
repo: 

https://github.com/ironhack-datalabs/scavenger

The filenames of the secret files contain .scavengerhunt and they are scattered in different directories 
of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are
scattered randomly throughout this repo. You need to search for these files by calling the Github API, 
not searching the local files on your computer.
'''

# %%
#GET /search/repositories
data_3=githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents").json()
# Out:
# We have a github token:  4660
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents

# %%
data_3

# %%
# lets see what is inside:
data_3[0].keys()
# Out:
# dict_keys(['name', 'path', 'sha', 'size', 'url', 'html_url', 'git_url', 'download_url', 'type', '_links'])

# %%
# all right. we need the paths:
caminitos=[]
for x in data_3:
    for y in x.items():
        if y[0]=="path":
            caminitos.append(y[1])
# caminitos
# the 1st element is not a scavenger pah, so lets toss it aside

# %%
caminitoDeBelen=[]
for x in caminitos[1:]:
    caminitoDeBelen.append(githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents/{}".format(x)).json())
# Out:
# We have a github token:  4660
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024
# We have a github token:  4660
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534
# We have a github token:  4660
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/17020
# We have a github token:  4660
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/30351
# We have a github token:  4660
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/40303
# We have a github token:  4660
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/44639
# We have a github token:  4660
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/scavenger/contents/45525
# We have a github token:  4660
# ...

# %%
caminitoDeBelen

# %%
caminitoAlPath=[]
for x in caminitoDeBelen:
    for y in x:
        for z in y.items():
            caminitoAlPath.append(z[1])
caminitoAlPath

# %%
# allright. we see some light here
import re
listascavenger=[]
for x in caminitoAlPath:
    if x==re.findall("(.+)?scavengerhunt",caminitoAlPath):
        listascavenger.append(x)
listascavenger

# %%
'''
ESTO ES DE ISA

# Acceso al archivo donde se encuentran las palabras
secret_file = []
for s in filtro_sorted:
    secret_file.append(githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents/{}".format(s)).json())
secret_file




# Contenido codificado
frase = []
for i in range(1, len(secret_file)):
    frase.append(secret_file[i]["content"])
print(frase)
len(frase)


# De-CODE base64
import base64



frase_limpia = []
for palabra in frase:
    frase_limpia.append(base64.b64decode(palabra))
print(frase_limpia)


# Quito (b)
limpia = re.sub("b+'", "", str(frase_limpia))
# Quito (\\n)
limpia1 = re.sub("\\\\n", "", str(limpia))
# Quito (')
limpia2 = re.sub("\'", "", str(limpia1))



# Quito (,) porque he intentado hacer join y en vez de juntarme por las comas, me hace un split de cada palabra por comas...
frase_final = re.sub("\,", "", str(limpia2))
frase_final


'''
# Out:
# '\nESTO ES DE ISA\n\n# Acceso al archivo donde se encuentran las palabras\nsecret_file = []\nfor s in filtro_sorted:\n    secret_file.append(githubRequestAuthorized("/repos/ironhack-datalabs/scavenger/contents/{}".format(s)).json())\nsecret_file\n\n\n\n\n# Contenido codificado\nfrase = []\nfor i in range(1, len(secret_file)):\n    frase.append(secret_file[i]["content"])\nprint(frase)\nlen(frase)\n\n\n# De-CODE base64\nimport base64\n\n\n\nfrase_limpia = []\nfor palabra in frase:\n    frase_limpia.append(base64.b64decode(palabra))\nprint(frase_limpia)\n\n\n# Quito (b)\nlimpia = re.sub("b+\'", "", str(frase_limpia))\n# Quito (\\n)\nlimpia1 = re.sub("\\\\n", "", str(limpia))\n# Quito (\')\nlimpia2 = re.sub("\'", "", str(limpia1))\n\n\n\n# Quito (,) porque he intentado hacer join y en vez de juntarme por las comas, me hace un split de cada palabra por comas...\nfrase_final = re.sub("\\,", "", str(limpia2))\nfrase_final\n\n\n'

# %%
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'dict'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'dict'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'dict'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'dict'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'dict'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'dict'>
# <class 'str'>
# <class 'str'>
# ...
