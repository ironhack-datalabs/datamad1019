# %%
# !pip3 install -U python-dotenv
# !pip3 install requests
# Out:
# Requirement already up-to-date: python-dotenv in /usr/local/lib/python3.7/site-packages (0.10.3)
# Collecting requests
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 3.9MB/s eta 0:00:01
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests)
#   Downloading https://files.pythonhosted.org/packages/e0/da/55f51ea951e1b7c63a579c09dd7db825bb730ec1fe9c0180fc77bfb31448/urllib3-1.25.6-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 4.5MB/s eta 0:00:01
# Collecting idna<2.9,>=2.5 (from requests)
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 7.0MB/s eta 0:00:011
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests) (3.0.4)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading https://files.pythonhosted.org/packages/18/b0/8146a4f8dd402f60744fa380bc73ca47303cccf8b9190fd16a827281eac2/certifi-2019.9.11-py2.py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 6.5MB/s eta 0:00:01
# Installing collected packages: urllib3, idna, certifi, requests
# Successfully installed certifi-2019.9.11 idna-2.8 requests-2.22.0 urllib3-1.25.6

# %%
import requests
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
def githubRequestAuthorized(resource):
    authToken = os.getenv("GITHUB_API_TOKEN")
    if not authToken:
        raise ValueError("NECESITAS UN TOKEN")
    else:
        print("We have a github token: ", authToken[0:4])
    headers = {
        "Authorization": "token {}".format(authToken)
    }
    url = "https://api.github.com{}".format(resource)
    print("Requesting authorized {}".format(url))
    res = requests.get(url, headers=headers)
    return res

# %%
data = githubRequestAuthorized("/repos/ironhack-datalabs/datamad1019/forks").json()
# Out:
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/ironhack-datalabs/datamad1019/forks

# %%
print(data)
# Out:
# [{'id': 218253546, 'node_id': 'MDEwOlJlcG9zaXRvcnkyMTgyNTM1NDY=', 'name': 'datamad1019', 'full_name': 'begoechavarren/datamad1019', 'private': False, 'owner': {'login': 'begoechavarren', 'id': 52955181, 'node_id': 'MDQ6VXNlcjUyOTU1MTgx', 'avatar_url': 'https://avatars1.githubusercontent.com/u/52955181?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/begoechavarren', 'html_url': 'https://github.com/begoechavarren', 'followers_url': 'https://api.github.com/users/begoechavarren/followers', 'following_url': 'https://api.github.com/users/begoechavarren/following{/other_user}', 'gists_url': 'https://api.github.com/users/begoechavarren/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/begoechavarren/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/begoechavarren/subscriptions', 'organizations_url': 'https://api.github.com/users/begoechavarren/orgs', 'repos_url': 'https://api.github.com/users/begoechavarren/repos', 'events_url': 'https://api.github.com/users/begoechavarren/events{/privacy}', 'received_events_url': 'https://api.github.com/users/begoechavarren/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/begoechavarren/datamad1019', 'description': None, 'fork': True, 'url': 'https://api.github.com/repos/begoechavarren/datamad1019', 'forks_url': 'https://api.github.com/repos/begoechavarren/datamad1019/forks', 'keys_url': 'https://api.github.com/repos/begoechavarren/datamad1019/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/begoechavarren/datamad1019/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/begoechavarren/datamad1019/teams', 'hooks_url': 'https://api.github.com/repos/begoechavarren/datamad1019/hooks', 'issue_events_url': 'https://api.github.com/repos/begoechavarren/datamad1019/issues/events{/number}', 'events_url': 'https://api.github.com/repos/begoechavarren/datamad1019/events', 'assignees_url': 'https://api.github.com/repos/begoechavarren/datamad1019/assignees{/user}', 'branches_url': 'https://api.github.com/repos/begoechavarren/datamad1019/branches{/branch}', 'tags_url': 'https://api.github.com/repos/begoechavarren/datamad1019/tags', 'blobs_url': 'https://api.github.com/repos/begoechavarren/datamad1019/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/begoechavarren/datamad1019/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/begoechavarren/datamad1019/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/begoechavarren/datamad1019/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/begoechavarren/datamad1019/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/begoechavarren/datamad1019/languages', 'stargazers_url': 'https://api.github.com/repos/begoechavarren/datamad1019/stargazers', 'contributors_url': 'https://api.github.com/repos/begoechavarren/datamad1019/contributors', 'subscribers_url': 'https://api.github.com/repos/begoechavarren/datamad1019/subscribers', 'subscription_url': 'https://api.github.com/repos/begoechavarren/datamad1019/subscription', 'commits_url': 'https://api.github.com/repos/begoechavarren/datamad1019/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/begoechavarren/datamad1019/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/begoechavarren/datamad1019/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/begoechavarren/datamad1019/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/begoechavarren/datamad1019/contents/{+path}', 'compare_url': 'https://api.github.com/repos/begoechavarren/datamad1019/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/begoechavarren/datamad1019/merges', 'archive_url': 'https://api.github.com/repos/begoechavarren/datamad1019/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/begoechavarren/datamad1019/downloads', 'issues_url': 'https://api.github.com/repos/begoechavarren/da ...

# %%
lst=[]
for x in data:
    for y,z in x.items():
        if y == "languages_url":
            lst.append(z)
print(lst)
# Out:
# ['https://api.github.com/repos/begoechavarren/datamad1019/languages', 'https://api.github.com/repos/mariobru/datamad1019/languages', 'https://api.github.com/repos/jlmingo/datamad1019/languages', 'https://api.github.com/repos/Ovion/datamad1019/languages', 'https://api.github.com/repos/ToniPons97/datamad1019/languages', 'https://api.github.com/repos/noeliacarrion/datamad1019/languages', 'https://api.github.com/repos/mariaadradosr/datamad1019/languages', 'https://api.github.com/repos/Juliopdata/datamad1019/languages', 'https://api.github.com/repos/guzmanueco/datamad1019/languages', 'https://api.github.com/repos/blancaalcala/datamad1019/languages', 'https://api.github.com/repos/AlexMndzF/datamad1019/languages', 'https://api.github.com/repos/David-Fde/datamad1019/languages', 'https://api.github.com/repos/MaikaRG/datamad1019/languages', 'https://api.github.com/repos/Turandot123/datamad1019/languages', 'https://api.github.com/repos/isagc/datamad1019/languages', 'https://api.github.com/repos/alfpml/datamad1019/languages', 'https://api.github.com/repos/mermora97/datamad1019/languages', 'https://api.github.com/repos/jm-cruz-d/datamad1019/languages', 'https://api.github.com/repos/blancalluch/datamad1019/languages', 'https://api.github.com/repos/albertovpd/datamad1019/languages', 'https://api.github.com/repos/mariaversin/datamad1019/languages', 'https://api.github.com/repos/seorakwon/datamad1019/languages', 'https://api.github.com/repos/Jpereza24/datamad1019/languages', 'https://api.github.com/repos/castares/datamad1019/languages', 'https://api.github.com/repos/progameitor/datamad1019/languages', 'https://api.github.com/repos/Masdevallia/datamad1019/languages', 'https://api.github.com/repos/cprietosegura/datamad1019/languages', 'https://api.github.com/repos/jgph91/datamad1019/languages', 'https://api.github.com/repos/alvarorivasg/datamad1019/languages', 'https://api.github.com/repos/Clapiniella/datamad1019/languages']

# %%
x = [githubRequestAuthorized(str(lan[22:])).json() for lan in lst]
# Out:
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/begoechavarren/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/mariobru/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/jlmingo/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/Ovion/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/ToniPons97/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/noeliacarrion/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/mariaadradosr/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/Juliopdata/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/guzmanueco/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/blancaalcala/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/AlexMndzF/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/David-Fde/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/MaikaRG/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/Turandot123/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/isagc/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/alfpml/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/mermora97/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/jm-cruz-d/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/blancalluch/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/albertovpd/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/mariaversin/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/seorakwon/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/Jpereza24/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/castares/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/progameitor/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/Masdevallia/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/cprietosegura/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/jgph91/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/alvarorivasg/datamad1019/languages
# We have a github token:  f9f1
# Requesting authorized https://api.github.com/repos/Clapiniella/datamad1019/languages

# %%
cosa=[]
for dicc in x:
    for key, value in dicc.items():
        cosa.append(key)

print(set(cosa))
# Out:
# {'HTML', 'Python', 'Jupyter Notebook'}
