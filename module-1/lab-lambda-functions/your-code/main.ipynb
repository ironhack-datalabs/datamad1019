# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %% [markdown]
# # Challenge 1 - Passing a Lambda Expression to a Function
#
# In the next excercise you will create a function that returns a lambda expression. Create a function called `modify_list`. The function takes two arguments, a list and a lambda expression. The function iterates through the list and applies the lambda expression to every element in the list.

# %% [raw]
# Follow the steps as stated below:
#     1. Define a list of any 10 numbers
#     2. Define a simple lambda expression for eg that updates a number by 2
#     3. Define an empty list
#     4. Define the function -> use the lambda function to append the empty list
#     5. Call the function with list and lambda expression
#     6. print the updated list

# %%
mista = random.sample(range(10000),10)
mista
# Out:
# [4298, 6988, 213, 6623, 4747, 2098, 4131, 3167, 1005, 3719]

# %%
import random

# %%
l = random.sample(range(10000),10)
print(l)
f = lambda x: x+2
b = []
def modify_list(lst, f):
    for x in lst:
        b.append(f(x))
modify_list(l,f)
print(b)
# Out:
# [8626, 9020, 1422, 3896, 8586, 6880, 9410, 369, 7770, 6539]
# [8628, 9022, 1424, 3898, 8588, 6882, 9412, 371, 7772, 6541]

# %% [markdown]
# #### Now we will define a lambda expression that will transform the elements of the list.
#
# In the cell below, create a lambda expression that converts Celsius to Kelvin. Recall that 0°C + 273.15 = 273.15K

# %%
# Your code here:
def tokelvin(c):
    return c+273.15

# %% [markdown]
# Finally, convert the list of temperatures below from Celsius to Kelvin.

# %%
temps = [12, 23, 38, -55, 24]

# Your code here:
[tokelvin(i) for i in temps]
# Out:
# [285.15, 296.15, 311.15, 218.14999999999998, 297.15]

# %% [markdown]
# #### In this part, we will define a function that returns a lambda expression
#
# In the cell below, write a lambda expression that takes two numbers and returns 1 if one is divisible by the other and zero otherwise. Call the lambda expression `mod`.

# %%
# Your code here:
mod=lambda x,y: 0 if x%y else 1

# %% [markdown]
# #### Now create a function that returns mod. The function only takes one argument - the first number in the `mod` lambda function.
#
# Note: the lambda function above took two arguments, the lambda function in the return statement only takes one argument but also uses the argument passed to the function.

# %%
def divisor(b):
    """
    input: a number
    output: a function that returns 1 if the number is divisible by another number (to be passed later) and zero otherwise
    """
    return lambda x: mod(x,b)
#   return lambda x: (lambda x,b: 0 if x%b else 1)

# %% [markdown]
# Finally, pass the number 5 to `divisor`. Now the function will check whether a number is divisble by 5. Assign this function to `divisible5`

# %%
# Your code here:
divisible5=divisor(5)
print(divisible5)
# Out:
# <function divisor.<locals>.<lambda> at 0x10f5871e0>

# %% [markdown]
# Test your function with the following test cases:

# %%
divisible5(10)
# Out:
# 1

# %%
divisor(5)(10)
# Out:
# 1

# %%
divisible5(8)
# Out:
# 0

# %% [markdown]
# # Challenge 2 - Using Lambda Expressions in List Comprehensions
#
# In the following challenge, we will combine two lists using a lambda expression in a list comprehension.
#
# To do this, we will need to introduce the `zip` function. The `zip` function returns an iterator of tuples.
#
# The way zip function works with list has been shown below:

# %%
list1 = ['Green', 'cheese', 'English', 'tomato']
list2 = ['eggs', 'cheese', 'cucumber', 'tomato']
zipped = zip(list1,list2)
list(zipped)
# Out:
# [('Green', 'eggs'),
#  ('cheese', 'cheese'),
#  ('English', 'cucumber'),
#  ('tomato', 'tomato')]

# %% [markdown]
# In this exercise we will try to compare the elements on the same index in the two lists.
# We want to zip the two lists and then use a lambda expression to compare if:
# list1 element > list2 element

# %%
list1 = [1,2,3,4]
list2 = [2,3,4,5]
zipizape=zip(list1,list2)
m=list(zipizape)

# %% [raw]
# Complete the parts of the code marked as "###"

# %%
compare = lambda x,y: print("True") if x==y else print("False")
for x,y in zip(list1,list2):
    compare(x,y)
# Out:
# False
# False
# False
# False

# %%
comparo = lambda x,y: print("True") if x==y else print("False")
for x in m:
    comparo(x[0],x[1])
# Out:
# False
# False
# False
# False

# %%
zipizape

# %% [markdown]
# # Challenge 3 - Using Lambda Expressions as Arguments
#
# #### In this challenge, we will zip together two lists and sort by the resulting tuple.
#
# In the cell below, take the two lists provided, zip them together and sort by the first letter of the second element of each tuple. Do this using a lambda function.

# %%
list1 = ['Engineering', 'Computer Science', 'Political Science', 'Mathematics']
list2 = ['Lab', 'Homework', 'Essay', 'Module']

# Your code here:
lost=list(zip(list1,list2))
print(lost)
sorted(lost,key=lambda x: x[1][0])
# Out:
# [('Engineering', 'Lab'), ('Computer Science', 'Homework'), ('Political Science', 'Essay'), ('Mathematics', 'Module')]
# [('Political Science', 'Essay'),
#  ('Computer Science', 'Homework'),
#  ('Engineering', 'Lab'),
#  ('Mathematics', 'Module')]

# %% [markdown]
# # Bonus Challenge - Sort a Dictionary by Values
#
# Given the dictionary below, sort it by values rather than by keys. Use a lambda function to specify the values as a sorting key.

# %%
d = {'Honda': 1997, 'Toyota': 1995, 'Audi': 2001, 'BMW': 2005}

# Your code here:
sorted([(v,k) for k,v in d.items()])
# Out:
# [(1995, 'Toyota'), (1997, 'Honda'), (2001, 'Audi'), (2005, 'BMW')]

# %%
sorted(d.items(),key=lambda x: x[1])
# Out:
# [('Toyota', 1995), ('Honda', 1997), ('Audi', 2001), ('BMW', 2005)]
