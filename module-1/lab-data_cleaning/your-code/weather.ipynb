# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
import os
import pandas as pd

# %%
weather = pd.read_csv("../weather-raw.csv")
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
stats = weather.drop(['id','year'], 1)
stats['average'] = stats.loc[:,'d2':'d31'].mean(axis=1)
filtered = stats.loc[:,['month','element','average']]
display(filtered)
# Out:
#     month element    average
# 0       1    tmax  27.800000
# 1       1    tmin  14.500000
# 2       2    tmax  27.750000
# 3       2    tmin  13.225000
# 4       3    tmax  32.566667
# 5       3    tmin  16.200000
# 6       4    tmax  36.300000
# 7       4    tmin  16.700000
# 8       5    tmax  33.200000
# 9       5    tmin  18.200000
# 10      6    tmax  29.050000
# 11      6    tmin  17.750000
# 12      7    tmax  29.250000
# 13      7    tmin  17.000000
# 14      8    tmax  28.271429
# 15      8    tmin  15.842857
# 16     10    tmax  28.900000
# 17     10    tmin  13.080000
# 18     11    tmax  28.120000
# 19     11    tmin  12.500000
# 20     12    tmax  27.800000
# 21     12    tmin  10.500000

# %%
tmax = filtered[filtered['element']=='tmax']
tmin = filtered[filtered['element']=='tmin']

final_table = pd.DataFrame.merge(tmax, tmin, on='month')
final_table.drop(['element_x','element_y'], 1)
final_table.rename(columns={'average_x': 'tmax','average_y':'tmin'})
# Out:
#     month element_x       tmax element_y       tmin
# 0       1      tmax  27.800000      tmin  14.500000
# 1       2      tmax  27.750000      tmin  13.225000
# 2       3      tmax  32.566667      tmin  16.200000
# 3       4      tmax  36.300000      tmin  16.700000
# 4       5      tmax  33.200000      tmin  18.200000
# 5       6      tmax  29.050000      tmin  17.750000
# 6       7      tmax  29.250000      tmin  17.000000
# 7       8      tmax  28.271429      tmin  15.842857
# 8      10      tmax  28.900000      tmin  13.080000
# 9      11      tmax  28.120000      tmin  12.500000
# 10     12      tmax  27.800000      tmin  10.500000

# %%
display(final_table)
# Out:
#     month element_x  average_x element_y  average_y
# 0       1      tmax  27.800000      tmin  14.500000
# 1       2      tmax  27.750000      tmin  13.225000
# 2       3      tmax  32.566667      tmin  16.200000
# 3       4      tmax  36.300000      tmin  16.700000
# 4       5      tmax  33.200000      tmin  18.200000
# 5       6      tmax  29.050000      tmin  17.750000
# 6       7      tmax  29.250000      tmin  17.000000
# 7       8      tmax  28.271429      tmin  15.842857
# 8      10      tmax  28.900000      tmin  13.080000
# 9      11      tmax  28.120000      tmin  12.500000
# 10     12      tmax  27.800000      tmin  10.500000
