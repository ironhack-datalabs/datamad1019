# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
import pandas as pd

# %%
#df = pd.read_csv('/Users/mariaadradosreig/Desktop/Ironhack/datamad1019/module-1/lab-data_cleaning/weather-raw.csv')

# %%
df = pd.read_csv('../weather-raw.csv')

# %%
df.head(17)
# Out:
#          id  year  month element  d1    d2    d3  d4    d5  d6  ...  d22  \
# 0   MX17004  2010      1    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN
# 1   MX17004  2010      1    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN
# 2   MX17004  2010      2    tmax NaN  27.3  24.1 NaN   NaN NaN  ...  NaN
# 3   MX17004  2010      2    tmin NaN  14.4  14.4 NaN   NaN NaN  ...  NaN
# 4   MX17004  2010      3    tmax NaN   NaN   NaN NaN  32.1 NaN  ...  NaN
# 5   MX17004  2010      3    tmin NaN   NaN   NaN NaN  14.2 NaN  ...  NaN
# 6   MX17004  2010      4    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN
# 7   MX17004  2010      4    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN
# 8   MX17004  2010      5    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN
# 9   MX17004  2010      5    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN
# 10  MX17004  2010      6    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN
# 11  MX17004  2010      6    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN
# ...

# %%
tmax_2 = pd.melt(df, id_vars = ['id','year', 'month', 'element'], value_name = 'tmax')
tmax_2.head()
# Out:
#         id  year  month element variable  tmax
# 0  MX17004  2010      1    tmax       d1   NaN
# 1  MX17004  2010      1    tmin       d1   NaN
# 2  MX17004  2010      2    tmax       d1   NaN
# 3  MX17004  2010      2    tmin       d1   NaN
# 4  MX17004  2010      3    tmax       d1   NaN

# %%
tmax_3 = tmax_2[['year', 'month', 'day', 'tmax']]
tmin_3 = tmin_2[['year', 'month', 'day', 'tmin']]

# %%
new = pd.merge(tmax_3, tmin_3)

# %%
filter = new[(new.tmax.notnull()) &(new.tmin.notnull())]

# %%
filter['day']= filter['day'].str.replace('d','')
filter.head()
# Out:
# /Users/mariaadradosreig/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     year  month day  tmax  tmin
# 10  2010     12   1  29.9  13.8
# 12  2010      2   2  27.3  14.4
# 20  2010     11   2  31.3  16.3
# 23  2010      2   3  24.1  14.4
# 28  2010      7   3  28.6  17.5

# %%
avg_mpg = filter.groupby('month', as_index=False).agg({'tmax':'mean'})

# %%
avg_mpg
# Out:
#     month       tmax
# 0       1  27.800000
# 1       2  27.750000
# 2       3  32.566667
# 3       4  36.300000
# 4       5  33.200000
# 5       6  29.050000
# 6       7  29.250000
# 7       8  28.271429
# 8      10  28.900000
# 9      11  28.120000
# 10     12  28.850000

# %%
avg_mpg = data.groupby('Make', as_index=False).agg({'Combined MPG':'mean'})

# %%
avg_temp =
