# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
import pandas as pd
import sqlalchemy as db
import getpass

# %%
data = pd.read_csv('../weather-raw.csv')
display(data)

data.dtypes
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...   \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
#new_column = list(data.loc[:,"d1":"d31"].columns)
#print(new_column)
colnames = ["Average", "Max", "Min"]
data_month = pd.DataFrame(columns = colnames)
for i in range(1,13):
    data_kpis = data[data['month'] == i].loc[:,"d1":"d31"]
    data_kpis["Average"]=(data_kpis.mean(axis=1))
    data_kpis["Max"] = data_kpis.max(axis=1)
    data_kpis["Min"] = data_kpis.min(axis=1)
    values = [data_kpis.loc[:,"Average"].mean(axis=0), data_kpis.loc[:,"Max"].max(axis=0), data_kpis.loc[:,"Min"].min(axis=0)]
    data_month.loc[i-1] = values
    #display(data_january)

data_month.index += 1
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
data_month.insert(loc=0, column = "Month", value = months)
display(data_month)
# Out:
#         Month    Average   Max   Min
# 1     January  21.150000  27.8  14.5
# 2    February  20.487500  29.9  10.7
# 3       March  24.383333  34.5  14.2
# 4       April  26.500000  36.3  16.7
# 5         May  25.700000  33.2  18.2
# 6        June  23.400000  30.1  17.5
# 7        July  23.125000  29.9  16.5
# 8      August  22.057143  29.8  15.0
# 9   September        NaN   NaN   NaN
# 10    October  20.990000  31.2  10.5
# 11   November  20.310000  31.3   7.9
# 12   December  20.500000  29.9  10.5
