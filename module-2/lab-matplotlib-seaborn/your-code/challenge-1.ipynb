# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplot(1,2,1)
plt.plot(x,y,linewidth=2,color="r")
plt.title("x,y")
plt.subplot(1,2,2)
plt.plot(x,z,linewidth=2,color="b")
plt.title("x,z")
# Out:
# Text(0.5, 1.0, 'x,z')

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
f,(ax1,ax2)=plt.subplots(1,2)
ax1.plot(x,y,color="r")
ax2.plot(x,z,color="b")

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
f,(ax1,ax2)=plt.subplots(1,2,figsize=(5,5))
ax1.plot(x,y,color="r")
ax2.plot(x,z,color="b")

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
f,(ax1,ax2)=plt.subplots(1,2,figsize=(10,7))
ax1.plot(x,y,color="r")
ax2.plot(x,z,color="b")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax2.set_xlabel("x")
ax2.set_ylabel("z")
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
fig, ax = plt.subplots(1, 2, figsize=(7,4))

ax[0].plot(x**2,color="g")
ax[0].plot(np.exp(x),color="r")
ax[0].set_yscale('linear')
ax[0].set_title("linear scale")

ax[1].plot(x**2,color="g")
ax[1].plot(np.exp(x),color="r")
ax[1].set_yscale('log')
ax[1].set_title("logaritmic scale")
# Out:
# Text(0.5, 1.0, 'logaritmic scale')

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
vehicles = pd.read_csv("vehicles.csv")

# %%
plt.scatter(x=vehicles["Combined MPG"],y=vehicles["Highway MPG"])

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
plt.boxplot(vehicles["CO2 Emission Grams/Mile"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1561dfdd0>,
#   <matplotlib.lines.Line2D at 0x1561e4390>],
#  'caps': [<matplotlib.lines.Line2D at 0x1561e4890>,
#   <matplotlib.lines.Line2D at 0x1561e4d90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1561df150>],
#  'medians': [<matplotlib.lines.Line2D at 0x1561ea310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1561ea810>],
#  'means': []}

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
plt.hist(vehicles["Fuel Barrels/Year"],bins=70)
# Out:
# (array([  60.,    0.,    5.,    0.,    5.,    6.,    5.,   10.,    4.,
#           21.,   37.,   88.,   95.,  119.,  260.,  423.,  884.,  653.,
#         1708., 1257., 1580., 1807., 2241., 3139., 3092., 3231.,    0.,
#         3529., 2308.,   79., 2226.,   65., 2210.,  138., 1940.,   86.,
#            0., 1275.,    0.,    0.,  735.,    0.,    0.,    0.,  439.,
#            0.,    0.,    0.,  130.,    0.,    0.,    0.,    0.,    0.,
#           36.,    0.,    0.,    0.,    0.,    0.,    0.,   21.,    0.,
#            0.,    0.,    0.,    0.,    0.,    0.,    5.]),
#  array([ 0.06      ,  0.73181633,  1.40363265,  2.07544898,  2.74726531,
#          3.41908163,  4.09089796,  4.76271429,  5.43453061,  6.10634694,
#          6.77816327,  7.44997959,  8.12179592,  8.79361224,  9.46542857,
#         10.1372449 , 10.80906122, 11.48087755, 12.15269388, 12.8245102 ,
#         13.49632653, 14.16814286, 14.83995918, 15.51177551, 16.18359184,
#         16.85540816, 17.52722449, 18.19904082, 18.87085714, 19.54267347,
#         20.2144898 , 20.88630612, 21.55812245, 22.22993878, 22.9017551 ,
#         23.57357143, 24.24538776, 24.91720408, 25.58902041, 26.26083673,
#         26.93265306, 27.60446939, 28.27628571, 28.94810204, 29.61991837,
#         30.29173469, 30.96355102, 31.63536735, 32.30718367, 32.979     ,
#         33.65081633, 34.32263265, 34.99444898, 35.66626531, 36.33808163,
#         37.00989796, 37.68171429, 38.35353061, 39.02534694, 39.69716327,
#         40.36897959, 41.04079592, 41.71261224, 42.38442857, 43.0562449 ,
#         43.72806122, 44.39987755, 45.07169388, 45.7435102 , 46.41532653,
#         47.08714286]),
#  <a list of 70 Patch objects>)

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
vehicles[["Fuel Type","City MPG"]].plot.bar
# Out:
# <bound method PlotAccessor.bar of <pandas.plotting._core.PlotAccessor object at 0x1562c5090>>
