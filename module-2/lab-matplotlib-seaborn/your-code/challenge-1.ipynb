# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# this is my favourite way to plot several plottings. it's easier to change stuff after

fig, ax = plt.subplots(2)
plt.style.use('default')
ax[0].plot(x,y, color="blue")
ax[1].plot(x,z, "--", color="red")

# %%
# other way
plt.figure ()
plt.subplot (1,2, 1)
plt.plot(x, y)
plt.subplot(1,2, 2)
plt.plot (x, z, color ='red')

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# figsize can be an argument of subplot

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# inserting labels to axis
fig, ax = plt.subplots(2, figsize=(10,10))

ax[0].plot(x,y, color="blue")
ax[0].set_xlabel("aprendizaje en IH")
ax[0].set_ylabel("nº de horas en IH")
ax[1].plot(x,z, "--", color="red")
ax[1].set_xlabel("la insoportable levedad del ser")
ax[1].set_ylabel("lo cansado que se hacen tantas horas en IH")
# Out:
# Text(0, 0.5, 'lo cansado que se hacen tantas horas en IH')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# changing the axis scale

import math
import numpy as np
y=np.power(x,2)
z=np.exp(x)


fig, ax = plt.subplots(2,figsize=(5,5))
plt.style.use('default')

ax[0].plot(x,z, color="blue")
ax[0].set_xlabel("pongo en el eje el tipo de escala")
ax[1].plot(x,z, "--", color="red")
ax[1].set_xlabel("escala logarítmica, base 2. presta atención a los ejes siempre")
ax[1].set_yscale('log', basey=2)

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
data=pd.read_csv("vehicles.csv")

# %%
# COSA IMPORTANTE: si usamos pandas hay cosas que no funcionan bien.
# por ejemplo, NO puedes poner set_xlabel, set_ylabel.. tienes que usar plt.xlabel, plt.ylabel

# esto me lo guardo para mi
data.plot("Combined MPG","Highway MPG", color="blue" )

plt.xlabel("Combined MPG")
plt.ylabel("Highway MPG")
# Out:
# Text(0, 0.5, 'Highway MPG')

# %%
# el ejercicio:
# scatter YA te pone los ejes POR DEFECTO
data.plot.scatter("Combined MPG","Highway MPG", color="blue" )

# %%
# Como tiene tendenia lineal, voy a ver la recta de mejor ajuste:
z=sns.lmplot(x="Combined MPG",y="Highway MPG", data=data )
# me frustra que no se vea la sombra englobando el coeficiente r², pero eso es para mi yo del futuro

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# to check the right name to look for
#plt.boxplot(Data["CO2 Emission Grams/Mile"])
col=[]
[col.append(e) for e in data]
col
# Out:
# ['Make',
#  'Model',
#  'Year',
#  'Engine Displacement',
#  'Cylinders',
#  'Transmission',
#  'Drivetrain',
#  'Vehicle Class',
#  'Fuel Type',
#  'Fuel Barrels/Year',
#  'City MPG',
#  'Highway MPG',
#  'Combined MPG',
#  'CO2 Emission Grams/Mile',
#  'Fuel Cost/Year']

# %%
plt.boxplot(data['CO2 Emission Grams/Mile'])
'''
Ordenar los datos y obtener el valor mínimo, el máximo, los cuartiles Q1, Q2 y Q3 y el rango intercuartílico (RIC):

En el ejemplo, para trazar la caja:

Valor 300..: es el Q1 (25% de los datos)
Valor 500: es el Q2 o mediana (el 50% de los datos)
Valor aprox 600: es el Q3 (75% de los datos)
Rango intercuartílico (Q3–Q1)

Los «bigotes», las líneas que se extienden desde la caja, se extienden hasta los valores máximo y mínimo de la serie
o hasta 1,5 veces el RIC.

Cuando los datos se extienden más allá de esto, significa que hay valores atípicos en la serie y entonces hay que 
calcular los límites superior e inferior, Li y Ls. 
'''
# Out:
# '\nOrdenar los datos y obtener el valor mínimo, el máximo, los cuartiles Q1, Q2 y Q3 y el rango intercuartílico (RIC):\n\nEn el ejemplo, para trazar la caja:\n\nValor 300..: es el Q1 (25% de los datos)\nValor 500: es el Q2 o mediana (el 50% de los datos)\nValor aprox 600: es el Q3 (75% de los datos)\nRango intercuartílico (Q3–Q1)\n\nLos «bigotes», las líneas que se extienden desde la caja, se extienden hasta los valores máximo y mínimo de la serie\no hasta 1,5 veces el RIC.\n\nCuando los datos se extienden más allá de esto, significa que hay valores atípicos en la serie y entonces hay que \ncalcular los límites superior e inferior, Li y Ls. \n'

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# HISTOGRAM
# bins are the number of divisions of the histogram

plt.hist(data['Fuel Cost/Year'],bins=15)
# Out:
# (array([3.0400e+02, 2.5350e+03, 9.0310e+03, 1.0386e+04, 7.5000e+03,
#         3.6350e+03, 1.3550e+03, 7.1300e+02, 4.0800e+02, 5.3000e+01,
#         1.7000e+01, 6.0000e+00, 4.0000e+00, 0.0000e+00, 5.0000e+00]),
#  array([ 600.        ,  946.66666667, 1293.33333333, 1640.        ,
#         1986.66666667, 2333.33333333, 2680.        , 3026.66666667,
#         3373.33333333, 3720.        , 4066.66666667, 4413.33333333,
#         4760.        , 5106.66666667, 5453.33333333, 5800.        ]),
#  <a list of 15 Patch objects>)

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# First, check the max value of the column. That will be the height
data['City MPG'].describe()
# Out:
# count    35952.000000
# mean        17.646139
# std          4.769349
# min          6.000000
# 25%         15.000000
# 50%         17.000000
# 75%         20.000000
# max         58.000000
# Name: City MPG, dtype: float64

# %%
plt.bar(data["Fuel Type"],data['City MPG'])
