# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import math

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.suptitle("Calling 'subplots' twice")
plt.plot(x,y,'-', color = 'purple', alpha = 0.5, linewidth=2, linestyle='dashed')
plt.xlabel('x')
plt.ylabel('y')
plt.subplot(1,2,2)
plt.subplots_adjust(wspace = 0.3)
plt.plot(x,z,'-', color = 'orange', alpha = 0.8, linewidth=2, linestyle='dashed')    
plt.xlabel('x')
plt.ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
f, (ax1, ax2) = plt.subplots(1, 2, sharey=False)
f.suptitle("Calling 'subplots' only once")
f.set_figwidth(12)
f.set_figheight(5)
f.subplots_adjust(wspace = 0.3)
ax1.plot(x,y,'-', color = 'purple', alpha = 0.5, linewidth=2, linestyle='dashed')
ax2.plot(x,z,'-', color = 'orange', alpha = 0.8, linewidth=2, linestyle='dashed')

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
f, (ax1, ax2) = plt.subplots(1, 2, sharey=False, figsize=(12,5))
f.suptitle("Calling 'subplots' only once")
f.subplots_adjust(wspace = 0.3)
ax1.plot(x,y,'-', color = 'purple', alpha = 0.5, linewidth=2, linestyle='dashed')
ax2.plot(x,z,'-', color = 'orange', alpha = 0.8, linewidth=2, linestyle='dashed')

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
f, (ax1, ax2) = plt.subplots(1, 2, sharey=False, figsize=(12,5))
f.suptitle("Calling 'subplots' only once")
f.subplots_adjust(wspace = 0.3)
ax1.plot(x,y,'-', color = 'purple', alpha = 0.5, linewidth=2, linestyle='dashed')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax2.plot(x,z,'-', color = 'orange', alpha = 0.8, linewidth=2, linestyle='dashed')
ax2.set_xlabel('x')
ax2.set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here

# Todo en un plot: Normal a la izquierda, Logarítmica a la derecha:

y = x**2
y2 = [math.exp(e) for e in x] # con np.exp no hace falta la list comprehension

fig, ax1 = plt.subplots()

color = 'tab:purple'
ax1.set_xlabel('x')
ax1.set_ylabel('y', color=color)
ax1.plot(x, y, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx() # instantiate a second axes that shares the same x-axis
color = 'tab:orange'
ax2.set_ylabel('y', color=color) # we already handled the x-label with ax1
ax2.set_yscale('log')
ax2.plot(x, y2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout() # otherwise the right y-label is slightly clipped
plt.show()

# %%
# Un plot para escala normal, y uno para escala logarítmica:

y = x**2
y2 = [math.exp(e) for e in x] # con np.exp no hace falta la list comprehension

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
ax1.plot(x, y, x, y2)
ax1.set_title('Normal scale')
ax2.plot(x, y,x, y2)
ax2.set_title('Logarithmic scale')
ax2.set_yscale("log")

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
vehicles = pd.read_csv('./vehicles.csv')

# %%
plt.scatter(vehicles['Combined MPG'], vehicles['Highway MPG'], color='purple', alpha=0.2)
plt.xlabel('Combined MPG')
plt.ylabel('Highway MPG')
plt.suptitle("Highway MPG ~ Combined MPG Scatter Plot")
# Out:
# Text(0.5, 0.98, 'Highway MPG ~ Combined MPG Scatter Plot')

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
# plt.boxplot(vehicles['CO2 Emission Grams/Mile'])
pd.plotting.boxplot(vehicles['CO2 Emission Grams/Mile'], grid = False)
plt.ylabel('CO2 Emission Grams/Mile')
plt.suptitle('CO2 Emission Grams/Mile Box Plot')
# Out:
# Text(0.5, 0.98, 'CO2 Emission Grams/Mile Box Plot')

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
with plt.xkcd():
    plt.hist(vehicles['Fuel Barrels/Year'],bins=10, color='purple', alpha=0.5)
    plt.suptitle('Fuel Barrels/Year Histogram')
    plt.xlabel('Fuel Barrels/Year')
# import antigravity

# %%
# your code here
vehicles['Fuel Barrels/Year'].hist(color='purple', alpha=0.8, grid = False)
plt.suptitle('Fuel Barrels/Year Histogram')
plt.xlabel('Fuel Barrels/Year')
# Out:
# Text(0.5, 0, 'Fuel Barrels/Year')

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# plt.bar(vehicles['Fuel Type'], vehicles['City MPG'])
# plt.xticks(vehicles['Fuel Type'], rotation=90)

# %%
with plt.xkcd():
    sns.set(style="white")
    plt.figure(figsize=(10,5))
    chart = sns.barplot(vehicles['Fuel Type'], vehicles['City MPG'], palette="vlag")
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='center')
